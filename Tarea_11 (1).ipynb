# %% [markdown]
# # Tarea: Uso de Condicionales (if / else)

# %% [markdown]
# ## Parte 1: Condicionales en la vida diaria
# Escribe 3 oraciones de situaciones reales donde usarías un "si... entonces...".
#
# Ejemplo:
# Si me despierto tarde, entonces llego tarde a la escuela.
#
# 1. Si estudio mucho, entonces aprobare el examen.
# 2. Si hace frio, entonces me pongo un abrigo.
# 3. Si tengo hambre, entonces comere algo.

# %% [markdown]
# ## Parte 2: Explicación de la importancia de las condicionales
# Explica 4 ejemplos donde se vea por qué son necesarias las condicionales.
#
# Ejemplo modelo:
#
#
# *   Situación: Decidir si llevo paraguas.
# *   Condición: Si está lloviendo.
# *   Si se cumple: Llevo paraguas.
# *   Si no se cumple: Salgo sin paraguas.
#
#
#
# 1.
# *   Situación: Decidir si voy al gimnasio.
# *   Condición: Si tengo tiempo libre.
# *   Si se cumple: Voy al gimnasio.
# *   Si no se cumple: Me quedo en casa.
#
# 2.
# *   Situación: Decidir si cocino.
# *   Condición: Si tengo los ingredientes.
# *   Si se cumple: Cocino.
# *   Si no se cumple: Pido comida a domicilio.
#
# 3.
# *   Situación: Decidir si estudio en la biblioteca.
# *   Condición: Si necesito un ambiente tranquilo.
# *   Si se cumple: Estudio en la biblioteca.
# *   Si no se cumple: Estudio en casa.
#
# 4.
# *   Situación: Decidir si voy a la fiesta.
# *   Condición: Si me siento con energia.
# *   Si se cumple: Voy a la fiesta.
# *   Si no se cumple: Me quedo en casa descansando.

# %% [markdown]
# ## Parte 3: Condicionales en Python

# %% [markdown]
# ### Ejercicio 1
#
# Pide la hora (0-23). Si es menor que 12 muestra 'Es mañana', si no 'Es tarde o noche'.

# %%
hora = int(input("Introduce la hora (0-23):"))

if hora < 12:
  print("Es mañana")
else:
  print("Es tarde o noche")
# Out:
# Introduce la hora (0-23):12
# Es tarde o noche

# %% [markdown]
# ### Ejercicio 2
# Pide dos números y muestra cuál es mayor o si son iguales.

# %%
# Escribe tu código aquí
num1 = float(input("Introduce el primer número:"))
num2 = float(input("Introduce el segundo número:"))

if num1 > num2:
  print("El primer número es mayor")
elif num1 < num2:
  print("El segundo número es mayor")
else:
  print("Los números son iguales")
# Out:
# Introduce el primer número:6
# Introduce el segundo número:4
# El primer número es mayor

# %% [markdown]
# ### Ejercicio 3
# Pide un número entero y muestra si es par o impar.

# %%
# Escribe tu código aquí

num = int(input("Introduce un número entero:"))

if num % 2 == 0:
  print("El número es par")
else:
  print("El número es impar")
# Out:
# Introduce un número entero:4
# El número es par
